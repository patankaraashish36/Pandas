# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/patan/Downloads/smartphones_cleaned_v6.csv")

# %%
df.head()
# Out:
#   brand_name                      model  price  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False
# 2    samsung      Samsung Galaxy A14 5G  16499    75.0    True    False
# 3   motorola       Motorola Moto G62 5G  14999    81.0    True    False
# 4     realme         Realme 10 Pro Plus  24999    82.0    True    False
#
#    has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# 0           False      snapdragon        8.0              3.2  ...
# 1           False      snapdragon        8.0              2.2  ...
# 2           False          exynos        8.0              2.4  ...
# 3           False      snapdragon        8.0              2.2  ...
# 4           False       dimensity        8.0              2.6  ...
#
#    refresh_rate  num_rear_cameras  num_front_cameras       os  \
# 0           120                 3                1.0  android
# ...

# %%
# Select Specific row.
df[["brand_name", "model", "price"]]
# Out:
#     brand_name                            model  price
# 0      oneplus                    OnePlus 11 5G  54999
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989
# 2      samsung            Samsung Galaxy A14 5G  16499
# 3     motorola             Motorola Moto G62 5G  14999
# 4       realme               Realme 10 Pro Plus  24999
# ..         ...                              ...    ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990
# 976      honor                      Honor X8 5G  14990
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990
# 978   motorola             Motorola Moto G91 5G  19990
# 979    samsung           Samsung Galaxy M52s 5G  24990
#
# [980 rows x 3 columns]

# %%
df[df["brand_name"] == "motorola"]
# Out:
#     brand_name                                      model  price  rating  \
# 3     motorola                       Motorola Moto G62 5G  14999    81.0
# 42    motorola                 Motorola Edge 20 Fusion 5G  18999    87.0
# 53    motorola                       Motorola Moto G82 5G  18999    83.0
# 59    motorola                          Motorola Moto G32  10499    75.0
# 80    motorola                       Motorola Moto G72 4G  15999    83.0
# 85    motorola                        Motorola Edge 30 5G  22999    83.0
# 92    motorola        Motorola Moto G62 (8GB RAM + 128GB)  16499    84.0
# 102   motorola                      Motorola Moto S30 Pro  23990    83.0
# 120   motorola                    Motorola Edge 30 Pro 5G  34999    89.0
# 126   motorola                          Motorola Moto G42  10999    78.0
# 132   motorola                          Motorola Moto E40   7999    71.0
# 151   motorola                          Motorola Moto G52  11999    75.0
# ...

# %%
df[(df["brand_name"] == "motorola") & (df["rating"] > 70)]

# df[(df['col1'] > 5) & (df['col2'] < 10)]
# Out:
#     brand_name                                  model  price  rating  has_5g  \
# 3     motorola                   Motorola Moto G62 5G  14999    81.0    True
# 42    motorola             Motorola Edge 20 Fusion 5G  18999    87.0    True
# 53    motorola                   Motorola Moto G82 5G  18999    83.0    True
# 59    motorola                      Motorola Moto G32  10499    75.0   False
# 80    motorola                   Motorola Moto G72 4G  15999    83.0   False
# 85    motorola                    Motorola Edge 30 5G  22999    83.0    True
# 92    motorola    Motorola Moto G62 (8GB RAM + 128GB)  16499    84.0    True
# 102   motorola                  Motorola Moto S30 Pro  23990    83.0    True
# 120   motorola                Motorola Edge 30 Pro 5G  34999    89.0    True
# 126   motorola                      Motorola Moto G42  10999    78.0   False
# 132   motorola                      Motorola Moto E40   7999    71.0   False
# ...

# %%
df.groupby("brand_name").size()
# Out:
# brand_name
# apple         46
# asus           7
# blackview      1
# blu            1
# cat            1
# cola           1
# doogee         2
# duoqin         1
# gionee         3
# google        14
# honor         13
# huawei        16
# ikall          3
# infinix       29
# iqoo          32
# itel          10
# jio            4
# lava           4
# leeco          1
# leitz          1
# lenovo         2
# letv           3
# lg             3
# lyf            2
# micromax       3
# motorola      52
# nokia         13
# nothing        5
# nubia          6
# oneplus       42
# oppo          88
# oukitel        3
# poco          41
# realme        97
# redmi          3
# royole         2
# samsung      132
# sharp          1
# sony           9
# tcl            1
# tecno         33
# tesla          1
# vertu          1
# vivo         111
# xiaomi       134
# zte            2
# dtype: int64

# %%
df.groupby("brand_name")["rating"].mean().round(2)
# Out:
# brand_name
# apple        76.80
# asus         87.00
# blackview    67.00
# blu          85.00
# cat            NaN
# cola         74.00
# doogee       86.00
# duoqin         NaN
# gionee       67.00
# google       77.33
# honor        78.18
# huawei       80.00
# ikall        60.67
# infinix      76.29
# iqoo         82.22
# itel         61.00
# jio          64.00
# lava         74.33
# leeco        65.00
# leitz        89.00
# lenovo       88.00
# letv         60.00
# lg           87.00
# lyf          60.00
# micromax     64.67
# motorola     80.10
# nokia        75.30
# nothing      85.20
# nubia        84.33
# oneplus      82.24
# oppo         78.73
# oukitel      79.33
# poco         78.70
# realme       76.45
# redmi        77.33
# royole       87.00
# samsung      78.72
# sharp        88.00
# sony         81.43
# tcl          60.00
# tecno        73.68
# tesla        83.00
# vertu        62.00
# vivo         77.16
# xiaomi       78.78
# zte          85.50
# ...

# %%
df.sort_values(by="rating", ascending = False)
# Out:
#     brand_name                        model   price  rating  has_5g  has_nfc  \
# 0      oneplus                OnePlus 11 5G   54999    89.0    True     True
# 359     xiaomi            Xiaomi 12T Pro 5G   59990    89.0    True     True
# 180    infinix           Infinix Zero Ultra   36999    89.0    True    False
# 694    samsung  Samsung Galaxy Note 10 Plus   58999    89.0   False     True
# 520     realme           Realme GT 2 Pro 5G   49959    89.0    True     True
# ..         ...                          ...     ...     ...     ...      ...
# 954     huawei                Huawei Mate X  169000     NaN    True     True
# 957       vivo                    Vivo Y55S   13490     NaN   False    False
# 963       lava                      Lava X3    6999     NaN   False    False
# 972       itel                    itel A23s    4787     NaN   False    False
# 974       vivo                Vivo X Fold 2  119990     NaN    True     True
#
# ...

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left: 'DataFrame | Series', right: 'DataFrame | Series', how: 'str' = 'inner', on: 'IndexLabel | None' = None, left_on: 'IndexLabel | None' = None, right_on: 'IndexLabel | None' = None, left_index: 'bool' = False, right_index: 'bool' = False, sort: 'bool' = False, suffixes: 'Suffixes' = ('_x', '_y'), copy: 'bool' = True, indicator: 'bool' = False, validate: 'str | None' = None) -> 'DataFrame'
#     Merge DataFrame or named Series objects with a database-style join.
#
#     A named Series object is treated as a DataFrame with a single named column.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
#     When performing a cross merge, no column specifications to merge on are
#     allowed.
#
#     .. warning::
#
# ...

# %%
pd.merge(df, df)
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999    81.0    True
# 4       realme               Realme 10 Pro Plus  24999    82.0    True
# ..         ...                              ...    ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 976      honor                      Honor X8 5G  14990    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...
